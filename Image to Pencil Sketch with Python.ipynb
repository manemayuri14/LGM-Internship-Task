# %% [markdown]
# ### LGM - VIRTUAL INTERNSHIP PROGRAM: DATA SCIENCE

# %% [markdown]
# ### TASK 1: Image to Pencil Sketch with Python

# %% [markdown]
# ### LEVEL: BEGINNER

# %% [markdown]
# ### FEBRUARY 2022

# %% [markdown]
# ### AUTHOR: MAYURI MANE

# %% [markdown]
# ### Import the Libraries

# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import numpy as np
from PIL import Image
from IPython.display import Image as display

# %% [markdown]
# ### Load the Image

# %%
loc='Dogs.jpg'
image = Image.open(loc)
print(image.size)
image1 = cv2.imread(loc)
cv2.imwrite(loc, image1)
display(filename=loc)
# Out:
# (640, 638)

# %% [markdown]
# ### Converting Image to Gray Scale

# %%
img = cv2.imread(loc)
grayed = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
print(grayed)
cv2.imwrite(loc, grayed)
display(filename=loc)
# Out:
# [[100 100 100 ...  98  98  98]
#  [100 100 100 ...  98  98  98]
#  [101 101 101 ...  98  98  98]
#  ...
#  [ 96  96  96 ...  95  94  93]
#  [ 95  95  95 ...  94  92  91]
#  [ 95  95  95 ...  93  92  91]]

# %%
inverted = cv2.bitwise_not(grayed)
cv2.imwrite("inverted.png", inverted)
display(filename="inverted.png")

# %% [markdown]
# ### Blurring the Image

# %%
blurred = cv2.GaussianBlur(inverted, (15, 15), sigmaX=0, sigmaY=0)
cv2.imwrite("blurred.png", blurred)
display(filename="blurred.png")

# %% [markdown]
# ### Converting Image to Pencil Sketch

# %%
def blend(x, y):
    return cv2.divide(x, 255 - y, scale=257)
final_result = blend(grayed, blurred)
cv2.imwrite("final.png", final_result)
display(filename="final.png")
